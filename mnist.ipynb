# %%
import keras
# print(keras.__version__)
# Out:
# 2026-03-24 09:47:16.453867: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-24 09:47:16.541977: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-24 09:47:18.773288: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# %%
x_train.shape,y_train.shape, x_test.shape,y_train.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (50000, 1))

# %%
import cv2

# %%
img_gray = cv2.cvtColor(x_train[0],cv2.COLOR_RGB2GRAY)
img_gray
# x_test[0]
# Out:
# array([[ 61,  45,  48, ..., 137, 130, 129],
#        [ 19,   0,  10, ...,  95,  90,  94],
#        [ 24,   9,  31, ...,  90,  91,  80],
#        ...,
#        [173, 154, 157, ..., 134,  36,  38],
#        [146, 129, 144, ..., 153,  69,  60],
#        [151, 137, 147, ..., 189, 124,  99]], shape=(32, 32), dtype=uint8)

# %%
import numpy as np
x_train_transformed = np.empty((50000,32,32))
x_train_transformed.shape
# Out:
# (50000, 32, 32)

# %%
for i in range(50000):
    x_train_transformed[i] = cv2.cvtColor(x_train[i],cv2.COLOR_RGB2GRAY)

x_train_transformed
# Out:
# array([[[ 61.,  45.,  48., ..., 137., 130., 129.],
#         [ 19.,   0.,  10., ...,  95.,  90.,  94.],
#         [ 24.,   9.,  31., ...,  90.,  91.,  80.],
#         ...,
#         [173., 154., 157., ..., 134.,  36.,  38.],
#         [146., 129., 144., ..., 153.,  69.,  60.],
#         [151., 137., 147., ..., 189., 124.,  99.]],
#
#        [[171., 134., 103., ...,  91.,  87.,  79.],
#         [155., 151., 124., ...,  96.,  77.,  71.],
#         [152., 144., 115., ...,  79.,  68.,  67.],
#         ...,
#         [169., 155., 159., ...,  37.,  56.,  87.],
#         [154., 151., 158., ...,  96., 117., 125.],
#         [149., 148., 155., ..., 137., 138., 137.]],
#
#        [[255., 253., 253., ..., 253., 253., 253.],
#         [255., 255., 255., ..., 255., 255., 255.],
#         [255., 254., 254., ..., 254., 254., 254.],
#         ...,
#         [117., 115., 109., ...,  78.,  77.,  77.],
#         [115., 108., 103., ...,  73.,  74.,  82.],
# ...

# %%
model = keras.Sequential()
model
# Out:
# <Sequential name=sequential, built=False>

# %%
model.add(keras.Input(shape=(32,32,3)))

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train_transformed[0],cmap='gray')

# %%
import numpy as np
x_train_trans_res = np.empty((50000,32,32))
x_train_trans_res.shape
# Out:
# (50000, 32, 32)

# %%
for i in range(50000):
    x_train_trans_res[i] = cv2.resize(x_train_transformed[i],(28,28),interpolation=cv2.INTER_LINEAR)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 for i in range(50000):
# ----> 2     x_train_trans_res[i] = cv2.resize(x_train_transformed[i],(28,28),interpolation=cv2.INTER_LINEAR)
#
# ValueError: could not broadcast input array from shape (28,28) into shape (32,32)
